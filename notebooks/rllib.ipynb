# %%
# !pip install ray[rllib]
# Out:
# Collecting ray[rllib]
#   Downloading ray-1.2.0-cp38-cp38-manylinux2014_x86_64.whl (47.3 MB)
#      |████████████████████████████████| 47.3 MB 47 kB/s
# Requirement already satisfied: grpcio>=1.28.1 in /home/teto/.local/share/virtualenvs/mesa-keras-rl-G6B7A4dF/lib/python3.8/site-packages (from ray[rllib]) (1.32.0)
# Requirement already satisfied: numpy>=1.16 in /home/teto/.local/share/virtualenvs/mesa-keras-rl-G6B7A4dF/lib/python3.8/site-packages (from ray[rllib]) (1.19.5)
# Requirement already satisfied: jsonschema in /home/teto/.local/share/virtualenvs/mesa-keras-rl-G6B7A4dF/lib/python3.8/site-packages (from ray[rllib]) (3.2.0)
# Requirement already satisfied: prometheus-client>=0.7.1 in /home/teto/.local/share/virtualenvs/mesa-keras-rl-G6B7A4dF/lib/python3.8/site-packages (from ray[rllib]) (0.9.0)
# Requirement already satisfied: protobuf>=3.8.0 in /home/teto/.local/share/virtualenvs/mesa-keras-rl-G6B7A4dF/lib/python3.8/site-packages (from ray[rllib]) (3.15.6)
# Requirement already satisfied: click>=7.0 in /home/teto/.local/share/virtualenvs/mesa-keras-rl-G6B7A4dF/lib/python3.8/site-packages (from ray[rllib]) (7.1.2)
# Requirement already satisfied: requests in /home/teto/.local/share/virtualenvs/mesa-keras-rl-G6B7A4dF/lib/python3.8/site-packages (from ray[rllib]) (2.25.1)
# Requirement already satisfied: pandas in /home/teto/.local/share/virtualenvs/mesa-keras-rl-G6B7A4dF/lib/python3.8/site-packages (from ray[rllib]) (1.2.3)
# Requirement already satisfied: gym[atari] in /home/teto/.local/share/virtualenvs/mesa-keras-rl-G6B7A4dF/lib/python3.8/site-packages (from ray[rllib]) (0.18.0)
# Requirement already satisfied: scipy in /home/teto/.local/share/virtualenvs/mesa-keras-rl-G6B7A4dF/lib/python3.8/site-packages (from ray[rllib]) (1.6.2)
# Requirement already satisfied: six>=1.5.2 in /home/teto/.local/share/virtualenvs/mesa-keras-rl-G6B7A4dF/lib/python3.8/site-packages (from grpcio>=1.28.1->ray[rllib]) (1.15.0)
# Collecting msgpack<2.0.0,>=1.0.0
#   Downloading msgpack-1.0.2-cp38-cp38-manylinux1_x86_64.whl (302 kB)
#      |████████████████████████████████| 302 kB 574 kB/s
# Collecting opencv-python-headless<=4.3.0.36
#   Downloading opencv_python_headless-4.3.0.36-cp38-cp38-manylinux2014_x86_64.whl (36.4 MB)
#      |████████████████████████████████| 36.4 MB 42 kB/s
# Collecting py-spy>=0.2.0
#   Downloading py_spy-0.3.5-py2.py3-none-manylinux1_x86_64.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 800 kB/s
# Collecting redis>=3.5.0
#   Downloading redis-3.5.3-py2.py3-none-any.whl (72 kB)
#      |████████████████████████████████| 72 kB 261 kB/s
# Collecting aiohttp
#   Downloading aiohttp-3.7.4.post0-cp38-cp38-manylinux2014_x86_64.whl (1.5 MB)
#      |████████████████████████████████| 1.5 MB 2.0 MB/s
# Requirement already satisfied: chardet<5.0,>=2.0 in /home/teto/.local/share/virtualenvs/mesa-keras-rl-G6B7A4dF/lib/python3.8/site-packages (from aiohttp->ray[rllib]) (4.0.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/teto/.local/share/virtualenvs/mesa-keras-rl-G6B7A4dF/lib/python3.8/site-packages (from aiohttp->ray[rllib]) (20.3.0)
# Requirement already satisfied: typing-extensions>=3.6.5 in /home/teto/.local/share/virtualenvs/mesa-keras-rl-G6B7A4dF/lib/python3.8/site-packages (from aiohttp->ray[rllib]) (3.7.4.3)
# Collecting async-timeout<4.0,>=3.0
#   Downloading async_timeout-3.0.1-py3-none-any.whl (8.2 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-5.1.0-cp38-cp38-manylinux2014_x86_64.whl (159 kB)
#      |████████████████████████████████| 159 kB 430 kB/s
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.6.3-cp38-cp38-manylinux2014_x86_64.whl (324 kB)
#      |████████████████████████████████| 324 kB 327 kB/s
# Requirement already satisfied: idna>=2.0 in /home/teto/.local/share/virtualenvs/mesa-keras-rl-G6B7A4dF/lib/python3.8/site-packages (from yarl<2.0,>=1.0->aiohttp->ray[rllib]) (2.10)
# Collecting aiohttp-cors
#   Downloading aiohttp_cors-0.7.0-py3-none-any.whl (27 kB)
# Collecting aioredis
#   Downloading aioredis-1.3.1-py3-none-any.whl (65 kB)
#      |████████████████████████████████| 65 kB 739 kB/s
# Collecting atari-py
#   Downloading atari-py-0.2.6.tar.gz (790 kB)
#      |████████████████████████████████| 790 kB 185 kB/s
# Collecting colorama
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Collecting colorful
#   Downloading colorful-0.5.4-py2.py3-none-any.whl (201 kB)
#      |████████████████████████████████| 201 kB 133 kB/s
# Collecting dm-tree
#   Downloading dm_tree-0.1.5-cp38-cp38-manylinux2014_x86_64.whl (91 kB)
#      |████████████████████████████████| 91 kB 223 kB/s
# Collecting filelock
#   Using cached filelock-3.0.12-py3-none-any.whl (7.6 kB)
# Collecting gpustat
#   Downloading gpustat-0.6.0.tar.gz (78 kB)
#      |████████████████████████████████| 78 kB 437 kB/s
# Collecting blessings>=1.6
#   Downloading blessings-1.7-py3-none-any.whl (18 kB)
# Collecting nvidia-ml-py3>=7.352.0
#   Downloading nvidia-ml-py3-7.352.0.tar.gz (19 kB)
# Requirement already satisfied: cloudpickle<1.7.0,>=1.2.0 in /home/teto/.local/share/virtualenvs/mesa-keras-rl-G6B7A4dF/lib/python3.8/site-packages (from gym[atari]->ray[rllib]) (1.6.0)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /home/teto/.local/share/virtualenvs/mesa-keras-rl-G6B7A4dF/lib/python3.8/site-packages (from gym[atari]->ray[rllib]) (1.5.0)
# Requirement already satisfied: Pillow<=7.2.0 in /home/teto/.local/share/virtualenvs/mesa-keras-rl-G6B7A4dF/lib/python3.8/site-packages (from gym[atari]->ray[rllib]) (7.2.0)
# Requirement already satisfied: opencv-python>=3. in /home/teto/.local/share/virtualenvs/mesa-keras-rl-G6B7A4dF/lib/python3.8/site-packages (from gym[atari]->ray[rllib]) (4.4.0.44)
# Requirement already satisfied: future in /home/teto/.local/share/virtualenvs/mesa-keras-rl-G6B7A4dF/lib/python3.8/site-packages (from pyglet<=1.5.0,>=1.4.0->gym[atari]->ray[rllib]) (0.18.2)
# Collecting hiredis
#   Downloading hiredis-2.0.0-cp38-cp38-manylinux2010_x86_64.whl (85 kB)
#      |████████████████████████████████| 85 kB 569 kB/s
# Requirement already satisfied: setuptools in /home/teto/.local/share/virtualenvs/mesa-keras-rl-G6B7A4dF/lib/python3.8/site-packages (from jsonschema->ray[rllib]) (51.1.1)
# Requirement already satisfied: pyrsistent>=0.14.0 in /home/teto/.local/share/virtualenvs/mesa-keras-rl-G6B7A4dF/lib/python3.8/site-packages (from jsonschema->ray[rllib]) (0.17.3)
# Collecting lz4
#   Downloading lz4-3.1.3-cp38-cp38-manylinux2010_x86_64.whl (1.8 MB)
#      |████████████████████████████████| 1.8 MB 639 kB/s
# Collecting opencensus
#   Downloading opencensus-0.7.12-py2.py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 538 kB/s
# Collecting opencensus-context==0.1.2
#   Downloading opencensus_context-0.1.2-py2.py3-none-any.whl (4.4 kB)
# Collecting google-api-core<2.0.0,>=1.0.0
#   Downloading google_api_core-1.26.3-py2.py3-none-any.whl (93 kB)
#      |████████████████████████████████| 93 kB 392 kB/s
# Requirement already satisfied: pytz in /home/teto/.local/share/virtualenvs/mesa-keras-rl-G6B7A4dF/lib/python3.8/site-packages (from google-api-core<2.0.0,>=1.0.0->opencensus->ray[rllib]) (2021.1)
# Requirement already satisfied: packaging>=14.3 in /home/teto/.local/share/virtualenvs/mesa-keras-rl-G6B7A4dF/lib/python3.8/site-packages (from google-api-core<2.0.0,>=1.0.0->opencensus->ray[rllib]) (20.9)
# Requirement already satisfied: google-auth<2.0dev,>=1.21.1 in /home/teto/.local/share/virtualenvs/mesa-keras-rl-G6B7A4dF/lib/python3.8/site-packages (from google-api-core<2.0.0,>=1.0.0->opencensus->ray[rllib]) (1.28.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /home/teto/.local/share/virtualenvs/mesa-keras-rl-G6B7A4dF/lib/python3.8/site-packages (from google-auth<2.0dev,>=1.21.1->google-api-core<2.0.0,>=1.0.0->opencensus->ray[rllib]) (4.2.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/teto/.local/share/virtualenvs/mesa-keras-rl-G6B7A4dF/lib/python3.8/site-packages (from google-auth<2.0dev,>=1.21.1->google-api-core<2.0.0,>=1.0.0->opencensus->ray[rllib]) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/teto/.local/share/virtualenvs/mesa-keras-rl-G6B7A4dF/lib/python3.8/site-packages (from google-auth<2.0dev,>=1.21.1->google-api-core<2.0.0,>=1.0.0->opencensus->ray[rllib]) (0.2.8)
# Collecting googleapis-common-protos<2.0dev,>=1.6.0
#   Downloading googleapis_common_protos-1.53.0-py2.py3-none-any.whl (198 kB)
#      |████████████████████████████████| 198 kB 682 kB/s
# Requirement already satisfied: pyparsing>=2.0.2 in /home/teto/.local/share/virtualenvs/mesa-keras-rl-G6B7A4dF/lib/python3.8/site-packages (from packaging>=14.3->google-api-core<2.0.0,>=1.0.0->opencensus->ray[rllib]) (2.4.7)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/teto/.local/share/virtualenvs/mesa-keras-rl-G6B7A4dF/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<2.0dev,>=1.21.1->google-api-core<2.0.0,>=1.0.0->opencensus->ray[rllib]) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in /home/teto/.local/share/virtualenvs/mesa-keras-rl-G6B7A4dF/lib/python3.8/site-packages (from requests->ray[rllib]) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/teto/.local/share/virtualenvs/mesa-keras-rl-G6B7A4dF/lib/python3.8/site-packages (from requests->ray[rllib]) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/teto/.local/share/virtualenvs/mesa-keras-rl-G6B7A4dF/lib/python3.8/site-packages (from pandas->ray[rllib]) (2.8.1)
# Collecting psutil
#   Downloading psutil-5.8.0-cp38-cp38-manylinux2010_x86_64.whl (296 kB)
#      |████████████████████████████████| 296 kB 848 kB/s
# Collecting pyyaml
#   Using cached PyYAML-5.4.1-cp38-cp38-manylinux1_x86_64.whl (662 kB)
# Collecting tabulate
#   Downloading tabulate-0.8.9-py3-none-any.whl (25 kB)
# Collecting tensorboardX
#   Downloading tensorboardX-2.2-py2.py3-none-any.whl (120 kB)
#      |████████████████████████████████| 120 kB 572 kB/s
# Building wheels for collected packages: atari-py, gpustat, nvidia-ml-py3
#   Building wheel for atari-py (setup.py) ... done
#   Created wheel for atari-py: filename=atari_py-0.2.6-cp38-cp38-linux_x86_64.whl size=2816103 sha256=24a0a1402c374349e4d8290793d18158a5736dab3a313b378980a47968b48fcf
#   Stored in directory: /home/teto/.cache/pip/wheels/7f/5e/27/2e90b9887063d82ee2f9f8b2f8db76bb2290aa281dc40449c8
#   Building wheel for gpustat (setup.py) ... done
#   Created wheel for gpustat: filename=gpustat-0.6.0-py3-none-any.whl size=12617 sha256=d3a33baf6e709618329fd996cd6d042c84e2d1ede304452024c988ad3b7a7f63
#   Stored in directory: /home/teto/.cache/pip/wheels/0d/d9/80/b6cbcdc9946c7b50ce35441cc9e7d8c5a9d066469ba99bae44
#   Building wheel for nvidia-ml-py3 (setup.py) ... done
#   Created wheel for nvidia-ml-py3: filename=nvidia_ml_py3-7.352.0-py3-none-any.whl size=19191 sha256=151238e1a7ad78ca7a67425cff8a56d951eddb67cd6815bc2a57621a9d3bc624
#   Stored in directory: /home/teto/.cache/pip/wheels/b9/b1/68/cb4feab29709d4155310d29a421389665dcab9eb3b679b527b
# Successfully built atari-py gpustat nvidia-ml-py3
# Installing collected packages: multidict, yarl, googleapis-common-protos, async-timeout, psutil, opencensus-context, nvidia-ml-py3, hiredis, google-api-core, blessings, aiohttp, redis, pyyaml, py-spy, opencensus, msgpack, gpustat, filelock, colorful, colorama, atari-py, aioredis, aiohttp-cors, tensorboardX, tabulate, ray, opencv-python-headless, lz4, dm-tree
# Successfully installed aiohttp-3.7.4.post0 aiohttp-cors-0.7.0 aioredis-1.3.1 async-timeout-3.0.1 atari-py-0.2.6 blessings-1.7 colorama-0.4.4 colorful-0.5.4 dm-tree-0.1.5 filelock-3.0.12 google-api-core-1.26.3 googleapis-common-protos-1.53.0 gpustat-0.6.0 hiredis-2.0.0 lz4-3.1.3 msgpack-1.0.2 multidict-5.1.0 nvidia-ml-py3-7.352.0 opencensus-0.7.12 opencensus-context-0.1.2 opencv-python-headless-4.3.0.36 psutil-5.8.0 py-spy-0.3.5 pyyaml-5.4.1 ray-1.2.0 redis-3.5.3 tabulate-0.8.9 tensorboardX-2.2 yarl-1.6.3
# WARNING: You are using pip version 20.3.3; however, version 21.0.1 is available.
# You should consider upgrading via the '/home/teto/.local/share/virtualenvs/mesa-keras-rl-G6B7A4dF/bin/python -m pip install --upgrade pip' command.

# %%
import ray
import ray.rllib.agents.ppo as ppo

ray.shutdown()
ray.init(ignore_reinit_error=True)
# Out:
# WARNING:tensorflow:From /home/teto/.local/share/virtualenvs/mesa-keras-rl-G6B7A4dF/lib/python3.8/site-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# 2021-04-05 12:07:44,996	INFO services.py:1172 -- View the Ray dashboard at http://127.0.0.1:8265
# {'node_ip_address': '192.168.43.113',
#  'raylet_ip_address': '192.168.43.113',
#  'redis_address': '192.168.43.113:6379',
#  'object_store_address': '/tmp/ray/session_2021-04-05_12-07-44_472602_12344/sockets/plasma_store',
#  'raylet_socket_name': '/tmp/ray/session_2021-04-05_12-07-44_472602_12344/sockets/raylet',
#  'webui_url': '127.0.0.1:8265',
#  'session_dir': '/tmp/ray/session_2021-04-05_12-07-44_472602_12344',
#  'metrics_export_port': 57831,
#  'node_id': 'b3b4826fd7b54bb232ef16c1c7c7a55a27adfb42dd84d0321f807bef'}

# %%
import os
import random
import argparse
import pandas as pd
from datetime import datetime

from ray.tune import run, sample_from
from ray.tune.schedulers import PopulationBasedTraining

# %%
# Postprocess the perturbed config to ensure it's still valid used if PBT.
def explore(config):
    # ensure we collect enough timesteps to do sgd
    if config["train_batch_size"] < config["sgd_minibatch_size"] * 2:
        config["train_batch_size"] = config["sgd_minibatch_size"] * 2
    # ensure we run at least one sgd iter
    if config["num_sgd_iter"] < 1:
        config["num_sgd_iter"] = 1
    return config

pbt = PopulationBasedTraining(
    time_attr="time_total_s",
    perturbation_interval=120,
    resample_probability=0.25,
    metric="episode_reward_mean",
    mode="max",
    # Specifies the mutations of these hyperparams
    hyperparam_mutations={
        "lambda": lambda: random.uniform(0.9, 1.0),
        "clip_param": lambda: random.uniform(0.01, 0.5),
        "lr": [1e-3, 5e-4, 1e-4, 5e-5, 1e-5],
        "num_sgd_iter": lambda: random.randint(1, 30),
        "sgd_minibatch_size": lambda: random.randint(128, 16384),
        "train_batch_size": lambda: random.randint(2000, 160000),
    },
    custom_explore_fn=explore)

# %%
analysis = run(
        'PPO',
        name="prueba_ppo",
        scheduler=pbt,
        num_samples=8,
        config={
            "env": "Taxi-v3",
            "seed": 123,
            "kl_coeff": 1.0,
            "num_gpus": 1,
            "num_workers": 1,
            "horizon": 99,
            "observation_filter": "MeanStdFilter",
            "model": {
                # "fcnet_hiddens": [
                #     32,
                #     32
                # ],
                "free_log_std": True
            },
            "num_sgd_iter": 10,
            "sgd_minibatch_size": 128,
            "lambda": sample_from(lambda spec: random.uniform(0.9, 1.0)),
            "clip_param": sample_from(lambda spec: random.uniform(0.1, 0.5)),
            "lr": sample_from(lambda spec: random.uniform(1e-3, 1e-5)),
            "train_batch_size": sample_from(
                lambda spec: random.randint(1000, 60000))
        })
print("best hyperparameters: ", analysis.best_config)

# %%
N_ITER = 30
results = []
episode_data = []
episode_json = []

for n in range(N_ITER):
    result = agent.train()
    results.append(result)
    
    episode = {'n': n, 
               'episode_reward_min': result['episode_reward_min'], 
               'episode_reward_mean': result['episode_reward_mean'], 
               'episode_reward_max': result['episode_reward_max'],  
               'episode_len_mean': result['episode_len_mean']
              }
    
    episode_data.append(episode)
    episode_json.append(json.dumps(episode))
    file_name = agent.save(CHECKPOINT_ROOT)
    
    print(f'{n+1:3d}: Min/Mean/Max reward: {result["episode_reward_min"]:8.4f}/{result["episode_reward_mean"]:8.4f}/{result["episode_reward_max"]:8.4f}, len mean: {result["episode_len_mean"]:8.4f}. Checkpoint saved to {file_name}')

# %%
policy = agent.get_policy()
model = policy.model
print(model.base_model.summary())

# %%
! rllib rollout \
    tmp/ppo/taxi/checkpoint_77/checkpoint-77 \
    --config "{\"env\": \"Taxi-v3\"}" \
    --run PPO \
    --steps 2000

# %%
# !tensorboard --logdir=$HOME/ray_results/

# %%
obs = env.reset()
done = False
episode_reward = 0
sum_reward = 0
n_step = 20
for step in range(n_step):
    action = agent.compute_action(obs)
    print(action)
    state, reward, done, info = env.step(action)
    print(state, reward, done, info)
    sum_reward += reward
    if done:
        print("cumulative reward", sum_reward)
        state = env.reset()
        sum_reward = 0
